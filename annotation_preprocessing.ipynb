    'Softdrink/27',
    'Softdrink/34',
    'Soups/2',
    'Soups/4',
    'Soups/5',
    'Soups/10',
    'Soups/77',
    'Soups/78',
    'Soups/79',
    'Soups/80',
    'Tea/19',
    'Tea/23',
    'Tea/29',
    'Tea/31',
    'Tea/32',
    'Tea/33',
    'Tea/34',
    'Tea/36',
    'Tea/43',
    'Tea/44',
    'Tea/45',
    'Tea/46',
    'Tea/48',
    'Tea/49',
    'Tea/50',
    'Tea/51',
    'Tea/54',
    'Tea/55',
    'Tea/57',
    'Tea/59',
    'Tea/60',
    'Tea/61',
    'Tea/62',
    'Tea/64',
    'Tea/65',
    'Tea/66',
    'Tea/67',
    'Tea/70',
    'Tea/71',
    'Tea/72',
    'Tea/73',
    'Tea/74',
    'Tea/75',
    'Tea/76',
    'Tea/77',
    'Tea/78',
    'Tea/80',
    'Tea/81',
    'Tea/82',
    'Tea/83',
    'SoftDrinks/26',
    'SoftDrinks/27',
    'SoftDrinks/34'
]

class_name_to_id_mapping = {}

for idx, item_class in enumerate(class_list):
    class_name_to_id_mapping[item_class] = idx

# %%
test_image_filename_pattern = re.compile("^s[0-9]")

image_path = 'yolov5/image/'
labels = [x for x in os.listdir(image_path) if ((x[-3:] == "txt") and not (test_image_filename_pattern.match(x[:2])))]
labels.sort()

# %%
labels
# Out:
# ['Biscuits_10.txt',
#  'Biscuits_103.txt',
#  'Biscuits_106.txt',
#  'Biscuits_108.txt',
#  'Biscuits_109.txt',
#  'Biscuits_113.txt',
#  'Biscuits_114.txt',
#  'Biscuits_115.txt',
#  'Biscuits_118.txt',
#  'Biscuits_119.txt',
#  'Biscuits_12.txt',
#  'Biscuits_13.txt',
#  'Biscuits_14.txt',
#  'Biscuits_17.txt',
#  'Biscuits_18.txt',
#  'Biscuits_19.txt',
#  'Biscuits_24.txt',
#  'Biscuits_28.txt',
#  'Biscuits_3.txt',
#  'Biscuits_30.txt',
#  'Biscuits_31.txt',
#  'Biscuits_32.txt',
#  'Biscuits_33.txt',
#  'Biscuits_34.txt',
#  'Biscuits_36.txt',
#  'Biscuits_37.txt',
#  'Biscuits_38.txt',
#  'Biscuits_39.txt',
#  'Biscuits_40.txt',
#  'Biscuits_44.txt',
#  'Biscuits_45.txt',
#  'Biscuits_47.txt',
#  'Biscuits_5.txt',
#  'Biscuits_52.txt',
#  'Biscuits_55.txt',
#  'Biscuits_6.txt',
#  'Biscuits_74.txt',
#  'Biscuits_76.txt',
#  'Biscuits_80.txt',
#  'Biscuits_91.txt',
#  'Biscuits_93.txt',
#  'Biscuits_96.txt',
#  'Biscuits_97.txt',
#  'Cereals_116.txt',
#  'Cereals_117.txt',
# ...

# %%
for filename in labels:
    with open(image_path+filename, "r+") as f:
        data = f.read() # read everything in the file
        try:
            old_class_id, xcentre, ycentre, width, height = data.split(' ')
        except:
            print(filename)
        
        class_name = filename.replace('_','/').replace('.txt','')
        new_class_id = class_name_to_id_mapping[class_name]
        
        f.seek(0)
        f.write(str(new_class_id)+" "+xcentre+" "+ycentre+" "+width+" "+height)
        
        f.close()

# %%
def get_info_dict(store_no, img_no):
    annotations_path = f'Planogram Dataset/annotations/s{store_no}_{img_no}.csv'
    anno = pd.read_csv(annotations_path, names=['class','xmin','ymin','xmax','ymax'])

    img_path = f'Grocery_products/Testing/store{store_no}/images/{img_no}.jpg'
    img = Image.open(img_path)
    
    info_dict = {}
    info_dict['bboxes'] = []
    info_dict['filename'] = f's{store_no}_{img_no}.jpg'
    info_dict['image_size'] = img.size
    
    img = img.save(f'image/s{store_no}_{img_no}.jpg')

    for idx, row in anno.iterrows():
        bbox = {}
        if len(row['class'].split('/')) == 3:
            class_category, item_name, item_no = row['class'].split('/')
        else:
            class_category, class_sub_category, item_name, item_no = row['class'].split('/')
        item_no = item_no[:-4]
        bbox['class'] = item_name +'/'+item_no
        bbox['xmin'] = row['xmin']
        bbox['ymin'] = row['ymin']
        bbox['xmax'] = row['xmax']
        bbox['ymax'] = row['ymax']
        info_dict['bboxes'].append(bbox)
    
    return info_dict

# %%
# Convert the info dict to the required yolo format and write it to disk
def convert_to_yolov5(info_dict):
    print_buffer = []
    
    # For each bounding box
    for b in info_dict["bboxes"]:
        try:
            class_id = class_name_to_id_mapping[b["class"]]
        except KeyError:
            print(b["class"])
            print("Invalid Class: " + b["class"])
        
        # Transform the bbox co-ordinates as per the format required by YOLO v5
        b_center_x = (b["xmin"] + b["xmax"]) / 2 
        b_center_y = (b["ymin"] + b["ymax"]) / 2
        b_width    = (b["xmax"] - b["xmin"])
        b_height   = (b["ymax"] - b["ymin"])
        
        # Normalise the co-ordinates by the dimensions of the image
        image_w, image_h = info_dict["image_size"]  
        image_c = 3
        b_center_x /= image_w 
        b_center_y /= image_h 
        b_width    /= image_w 
        b_height   /= image_h 
        
        #Write the bbox details to the file 
        print_buffer.append("{} {:.3f} {:.3f} {:.3f} {:.3f}".format(class_id, b_center_x, b_center_y, b_width, b_height))
        
    # Name of the file which we have to save 
    save_file_name = os.path.join("image", info_dict["filename"].replace("jpg", "txt"))
    
    # Save the annotation to disk
    print("\n".join(print_buffer), file= open(save_file_name, "w"))

# %%
# Get the annotations
annotations = [os.path.join('annotations', x) for x in os.listdir('Planogram Dataset/annotations/') if x[-3:] == "csv"]
annotations.sort()

# %%
import re
# Convert and save the annotations
for ann in annotations:
    print(ann)
    store_no, image_no = re.findall(r'\d+', ann)
    info_dict = get_info_dict(store_no, image_no)
    convert_to_yolov5(info_dict)

annotations = [os.path.join('shelf_image', x) for x in os.listdir('shelf_image/') if x[-3:] == "txt"]
# Out:
# annotations/s1_14.csv
# annotations/s1_15.csv
# annotations/s1_43.csv
# annotations/s1_44.csv
# annotations/s1_46.csv
# annotations/s2_1.csv
# annotations/s2_10.csv
# annotations/s2_108.csv
# annotations/s2_11.csv
# annotations/s2_124.csv
# annotations/s2_125.csv
# annotations/s2_126.csv
# annotations/s2_129.csv
# annotations/s2_131.csv
# annotations/s2_136.csv
# annotations/s2_14.csv
# annotations/s2_140.csv
# annotations/s2_143.csv
# annotations/s2_157.csv
# annotations/s2_16.csv
# annotations/s2_17.csv
# annotations/s2_18.csv
# annotations/s2_2.csv
# annotations/s2_26.csv
# annotations/s2_29.csv
# annotations/s2_3.csv
# annotations/s2_30.csv
# annotations/s2_4.csv
# annotations/s2_5.csv
# annotations/s2_6.csv
# annotations/s2_8.csv
# annotations/s2_9.csv
# annotations/s3_110.csv
# annotations/s3_111.csv
# annotations/s3_112.csv
# annotations/s3_113.csv
# annotations/s3_114.csv
# annotations/s3_115.csv
# annotations/s3_116.csv
# annotations/s3_117.csv
# annotations/s3_118.csv
# ...

# %%
testing_image_list = [os.path.join('shelf_image', x) for x in os.listdir('shelf_image/') if x[-3:] == "jpg"]
training_image_list = [os.path.join('shelf_image', x) for x in os.listdir('yolov5/image/') if x[-3:] == "jpg"]

# %%
training_image_list.sort()
training_image_list
# Out:
# ['image/Biscuits_10.jpg',
#  'image/Biscuits_103.jpg',
#  'image/Biscuits_106.jpg',
#  'image/Biscuits_108.jpg',
#  'image/Biscuits_109.jpg',
#  'image/Biscuits_113.jpg',
#  'image/Biscuits_114.jpg',
#  'image/Biscuits_115.jpg',
#  'image/Biscuits_118.jpg',
#  'image/Biscuits_119.jpg',
#  'image/Biscuits_12.jpg',
#  'image/Biscuits_13.jpg',
#  'image/Biscuits_14.jpg',
#  'image/Biscuits_17.jpg',
#  'image/Biscuits_18.jpg',
#  'image/Biscuits_19.jpg',
#  'image/Biscuits_24.jpg',
#  'image/Biscuits_28.jpg',
#  'image/Biscuits_3.jpg',
#  'image/Biscuits_30.jpg',
#  'image/Biscuits_31.jpg',
#  'image/Biscuits_32.jpg',
#  'image/Biscuits_33.jpg',
#  'image/Biscuits_34.jpg',
#  'image/Biscuits_36.jpg',
#  'image/Biscuits_37.jpg',
#  'image/Biscuits_38.jpg',
#  'image/Biscuits_39.jpg',
#  'image/Biscuits_40.jpg',
#  'image/Biscuits_44.jpg',
#  'image/Biscuits_47.jpg',
#  'image/Biscuits_5.jpg',
#  'image/Biscuits_52.jpg',
#  'image/Biscuits_55.jpg',
#  'image/Biscuits_6.jpg',
# ...

# %%
import random
import numpy as np

random.seed(0)

class_id_to_name_mapping = dict(zip(class_name_to_id_mapping.values(), class_name_to_id_mapping.keys()))

def plot_bounding_box(image, annotation_list):
    annotations = np.array(annotation_list)
    w, h = image.size
    
    plotted_image = ImageDraw.Draw(image)

    transformed_annotations = np.copy(annotations)
    transformed_annotations[:,[1,3]] = annotations[:,[1,3]] * w
    transformed_annotations[:,[2,4]] = annotations[:,[2,4]] * h 
    
    transformed_annotations[:,1] = transformed_annotations[:,1] - (transformed_annotations[:,3] / 2)
    transformed_annotations[:,2] = transformed_annotations[:,2] - (transformed_annotations[:,4] / 2)
    transformed_annotations[:,3] = transformed_annotations[:,1] + transformed_annotations[:,3]
    transformed_annotations[:,4] = transformed_annotations[:,2] + transformed_annotations[:,4]

    font_path = 'OpenSans-Regular.ttf'
    font = ImageFont.truetype(font_path, size=60, )
    
    for ann in transformed_annotations:
        obj_cls, x0, y0, x1, y1 = ann
        plotted_image.rectangle(((x0,y0), (x1,y1)), width=5, outline="Red")
        plotted_image.text((x0, y0 - 10), class_id_to_name_mapping[(int(obj_cls))], fill="Red", font=font, stroke_width=3)

    image.show()

# Get any random annotation file 
# annotation_file = 'yolov5/image/Biscuits_3.txt'
annotation_file = random.choice(annotations)
with open(annotation_file, "r") as file:
    annotation_list = file.read().split("\n")[:-1]
#     annotation_list = ["0 0.500665 0.485184 0.977394 0.952460"]
    annotation_list = [x.split(" ") for x in annotation_list]
    annotation_list = [[float(y) for y in x ] for x in annotation_list]

#Get the corresponding image file
# image_file = 'yolov5/image/Biscuits_3.jpg'
image_file = annotation_file.replace("annotations", "images").replace("txt", "jpg")
assert os.path.exists(image_file)

#Load the image
image = Image.open(image_file)

#Plot the Bounding Box
plot_bounding_box(image, annotation_list)

# %%
len(annotations)
# Out:
# 74

# %%
len(class_id_to_name_mapping)
# Out:
# 213
